# %% [markdown]
# <a href="https://colab.research.google.com/github/radhikash21/Bootcamp_ML_Notebooks/blob/main/session3_S4_btach2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str_str = 'radhika'
int_int = 2
float_float = 18.5
bool_bool = True

print(str_str)
print(int_int)
print(float_float)
print(bool_bool)
# Out:
# radhika
# 2
# 18.5
# True

# %%
subjects = ['calculus','algebra','DBMS','data engineering','Python']
print(subjects[0],subjects[-1])
# Out:
# calculus Python

# %%
student_marks = [30,50,70,80,95]
for i in student_marks:
  if(i>=40 and i<=100):
    print("PASS")
  elif(i>=0 and i<40):
    print("FAIL")
  else:
    print("WRONG INPUT")
# Out:
# FAIL
# PASS
# PASS
# PASS
# PASS

# %%
num = map(int,input().split())
for i in num:
  if(i>0):
    print("Number is POSITIVE")
  elif(i<0):
    print("Number is NEGATIVE")
  elif(i==0):
    print("Number is ZERO")
# Out:
# 1
# Number is POSITIVE

# %%
stu1={
    'name':'Radhika',
    'study_hours':3,
    'attendance':100,
    'marks':80
}
stu2={
    'name':'Deeksha',
    'study_hours':6,
    'attendance':90,
    'marks':77
}
stu3={
    'name':'Richa',
    'study_hours':7,
    'attendance':60,
    'marks':35
}
stu4={
    'name':'Divyanshu',
    'study_hours':4,
    'attendance':90,
    'marks':70
}
students_details=[stu1,stu2,stu3,stu4]
input_name=input()
for i in students_details:
  if(input_name==i):
    if(i[1]<4):
      print("need to improve")
    if(i[2]<75):
      print("waring attendance is low")
    if(i[3]>=75):
      print("strong")
    if(i[3]>=40 and marks<75):
      print("needs improvement")
    if(i[3]<40):
      print("work on your self")
# Out:
# Radhika

# %%
# Student Starter Code
transactions = [
    {"transaction_id": "TX101", "amount": 6200, "method": "Credit Card"},
    {"transaction_id": "TX102", "amount": 5500, "method": "Gift Card"},
    {"transaction_id": "TX103", "amount": 1200, "method": "Gift Card"},
    {"transaction_id": "TX104", "amount": 8000, "method": "Gift Card"},
    {"transaction_id": "TX105", "amount": 450, "method": "PayPal"}
]

flagged_transactions = []

# Write your code below to find anomalous patterns
for transaction in transactions:
    if (transaction["amount"]>5000 and transaction["method"]=="Gift Card"):
        flagged_transactions.append(transaction["transaction_id"])
print(flagged_transactions)
# Out:
# ['TX102', 'TX104']

# %%
def pass_fail(marks):
  for i in marks:
    if(i>=27):
      print("PASS")
    else:
      print("FAIL")
print(pass_fail([10,20,45,47,27]))
# Out:
# FAIL
# FAIL
# PASS
# PASS
# PASS
# None

# %%
import numpy as np
marks = np.array([78, 91, 55, 72, 40, 88,98,81,11,23,78,88,91,96])
print("avg: ",sum(marks)/len(marks))
print("highest: ",max(marks))
print("lowest: ",min(marks))
count=0
for i in marks:
  if(i>75):
    count+=1
print(count)
# Out:
# avg:  70.71428571428571
# highest:  98
# lowest:  11
# 9

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0358d78f-534e-4d00-9ec7-321e0f3b2e28" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0358d78f-534e-4d00-9ec7-321e0f3b2e28">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("session4_dummy_students_data.csv.xls")
print(df)
# Out:
#     student_id    name  age     city  math  science  english  \
# 0          101   Aarav   16   Mumbai    78       84       69
# 1          102    Diya   16    Delhi    91       88       94
# 2          103   Kabir   17  Mathura    55       61       58
# 3          104   Meera   16    Noida    72       79       81
# 4          105   Rohan   17   Mumbai    40       52       47
# 5          106    Sara   16    Delhi    88       93       90
# 6          107  Ishaan   17  Mathura    64       70       66
# 7          108  Ananya   16    Noida    95       92       89
# 8          109  Vivaan   17   Mumbai    48       57       51
# 9          110    Tara   16    Delhi    83       76       85
# 10         111   Arjun   17  Mathura    67       63       72
# 11         112   Nisha   16    Noida    74       81       79
# 12         113     Dev   17   Mumbai    35       45       42
# 13         114   Priya   16    Delhi    89       86       91
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             20 non-null     int64
#  1   name                   20 non-null     object
#  2   age                    20 non-null     int64
#  3   city                   20 non-null     object
#  4   math                   20 non-null     int64
#  5   science                20 non-null     int64
#  6   english                20 non-null     int64
#  7   attendance_percent     20 non-null     int64
#  8   study_hours_per_week   20 non-null     int64
#  9   assignments_submitted  20 non-null     int64
#  10  final_project_score    20 non-null     int64
# dtypes: int64(9), object(2)
# memory usage: 1.8+ KB

# %%
df.describe()
# Out:
#        student_id        age       math    science    english  \
# count    20.00000  20.000000  20.000000  20.000000  20.000000
# mean    110.50000  16.450000  69.500000  72.350000  72.200000
# std       5.91608   0.510418  18.446223  15.383775  17.157475
# min     101.00000  16.000000  35.000000  45.000000  42.000000
# 25%     105.75000  16.000000  57.250000  60.000000  59.500000
# 50%     110.50000  16.000000  73.000000  74.500000  75.500000
# 75%     115.25000  17.000000  84.250000  85.250000  86.000000
# max     120.00000  17.000000  95.000000  93.000000  96.000000
#
#        attendance_percent  study_hours_per_week  assignments_submitted  \
# count           20.000000             20.000000              20.000000
# mean            83.850000              7.250000               7.750000
# std             11.089469              3.092861               1.915999
# min             62.000000              2.000000               4.000000
# ...
